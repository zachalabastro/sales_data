# %%
import pandas as pd

df_1 = pd.read_csv('fct_invoice.csv')
# Out:
#       invoice_no  customer_id         category  quantity    price  \
# 0        I138884          229         Clothing         5  1500.40
# 1        I317333         3433            Shoes         3  1800.51
# 2        I127801          644         Clothing         1   300.08
# 3        I173702         4900            Shoes         5  3000.85
# 4        I337046         1089            Books         4    60.60
# ...          ...          ...              ...       ...      ...
# 99452    I219422         2344         Souvenir         5    58.65
# 99453    I325143          172  Food & Beverage         2    10.46
# 99454    I824010          425  Food & Beverage         2    10.46
# 99455    I702964          577       Technology         4  4200.00
# 99456    I232867           30         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# ...

# %%
df_2 = pd.read_json('dim_customer.json')
# Out:
#        age first_name gender     id last_name
# 0     48.0   Nicholas      M      0    Flores
# 1      NaN    Jeffery      M      1      Rowe
# 2     57.0     Alexis      F      2    Benton
# 3     73.0        Amy      F      3   Johnson
# 4     20.0      David      M      4     Moore
# ...    ...        ...    ...    ...       ...
# 5186   NaN     Arthur      M   9428    Harris
# 5187   NaN      David      M   9494       Roy
# 5188  85.0     Thomas      M  10350    Turner
# 5189   NaN      April      F  10587   Sanchez
# 5190   NaN     Andrew      M  10934   Compton
#
# [5191 rows x 5 columns]

# %% [markdown]
# # Easy Questions

# %% [markdown]
# ## Question 1

# %%
import pandas as pd

df_1 = pd.read_csv('fct_invoice.csv')
df_2 = pd.read_json('dim_customer.json')

df_1
# Out:
#       invoice_no  customer_id         category  quantity    price  \
# 0        I138884          229         Clothing         5  1500.40
# 1        I317333         3433            Shoes         3  1800.51
# 2        I127801          644         Clothing         1   300.08
# 3        I173702         4900            Shoes         5  3000.85
# 4        I337046         1089            Books         4    60.60
# ...          ...          ...              ...       ...      ...
# 99452    I219422         2344         Souvenir         5    58.65
# 99453    I325143          172  Food & Beverage         2    10.46
# 99454    I824010          425  Food & Beverage         2    10.46
# 99455    I702964          577       Technology         4  4200.00
# 99456    I232867           30         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# ...

# %%
df_1['customer_id'].nunique()
# Out:
# 5191

# %% [markdown]
# ## Question 2

# %%
df_1
# Out:
#       invoice_no  customer_id         category  quantity    price  \
# 0        I138884          229         Clothing         5  1500.40
# 1        I317333         3433            Shoes         3  1800.51
# 2        I127801          644         Clothing         1   300.08
# 3        I173702         4900            Shoes         5  3000.85
# 4        I337046         1089            Books         4    60.60
# ...          ...          ...              ...       ...      ...
# 99452    I219422         2344         Souvenir         5    58.65
# 99453    I325143          172  Food & Beverage         2    10.46
# 99454    I824010          425  Food & Beverage         2    10.46
# 99455    I702964          577       Technology         4  4200.00
# 99456    I232867           30         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# ...

# %%
categories = df_1['category']

categories
# Out:
# 0               Clothing
# 1                  Shoes
# 2               Clothing
# 3                  Shoes
# 4                  Books
#               ...
# 99452           Souvenir
# 99453    Food & Beverage
# 99454    Food & Beverage
# 99455         Technology
# 99456           Souvenir
# Name: category, Length: 99457, dtype: object

# %%
categories.unique()
# Out:
# array(['Clothing', 'Shoes', 'Books', 'Cosmetics', 'Food & Beverage',
#        'Toys', 'Technology', 'Souvenir'], dtype=object)

# %%
categories.nunique()
# Out:
# 8

# %% [markdown]
# ## Question 3

# %%
payment_methods = df['payment_method']

payment_methods
# Out:
# 0        Credit Card
# 1         Debit Card
# 2               Cash
# 3        Credit Card
# 4               Cash
#             ...
# 99452    Credit Card
# 99453           Cash
# 99454     Debit Card
# 99455           Cash
# 99456    Credit Card
# Name: payment_method, Length: 99457, dtype: object

# %%
payment_methods.value_counts()
# Out:
# Cash           44447
# Credit Card    34931
# Debit Card     20079
# Name: payment_method, dtype: int64

# %%
#Cash was used the most, with a total of 44447 uses.

# %% [markdown]
# # Medium

# %% [markdown]
# ## Question 1

# %%
import pandas as pd

df_1 = pd.read_csv('fct_invoice.csv')
df_2 = pd.read_json('dim_customer.json')

df_2
# Out:
#        age first_name gender     id last_name
# 0     48.0   Nicholas      M      0    Flores
# 1      NaN    Jeffery      M      1      Rowe
# 2     57.0     Alexis      F      2    Benton
# 3     73.0        Amy      F      3   Johnson
# 4     20.0      David      M      4     Moore
# ...    ...        ...    ...    ...       ...
# 5186   NaN     Arthur      M   9428    Harris
# 5187   NaN      David      M   9494       Roy
# 5188  85.0     Thomas      M  10350    Turner
# 5189   NaN      April      F  10587   Sanchez
# 5190   NaN     Andrew      M  10934   Compton
#
# [5191 rows x 5 columns]

# %%
#For question 1, I did not know if the price already accounted for the quantity, so I just multiplied it with each other to get the total value of the order.

df_1['total_sales'] = df_1['quantity'] * df_1['price']

df_1['total_sales']

df_1

df_1.groupby('category').sum()['total_sales']
# Out:
# /var/folders/4w/kmgy8kbd69g6vxk5z4c_h4340000gn/T/ipykernel_22004/551152998.py:9: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_1.groupby('category').sum()['total_sales']
# category
# Books              8.345529e+05
# Clothing           1.139968e+08
# Cosmetics          6.792863e+06
# Food & Beverage    8.495351e+05
# Shoes              6.655345e+07
# Souvenir           6.358247e+05
# Technology         5.786235e+07
# Toys               3.980426e+06
# Name: total_sales, dtype: float64

# %%
#Books, clothing, and cosmetics were the three most popular categories by total sales.

# %% [markdown]
# ## Question 2

# %%
import pandas as pd

df_1 = pd.read_csv('fct_invoice.csv')
df_2 = pd.read_json('dim_customer.json')

df_2
# Out:
#        age first_name gender     id last_name
# 0     48.0   Nicholas      M      0    Flores
# 1      NaN    Jeffery      M      1      Rowe
# 2     57.0     Alexis      F      2    Benton
# 3     73.0        Amy      F      3   Johnson
# 4     20.0      David      M      4     Moore
# ...    ...        ...    ...    ...       ...
# 5186   NaN     Arthur      M   9428    Harris
# 5187   NaN      David      M   9494       Roy
# 5188  85.0     Thomas      M  10350    Turner
# 5189   NaN      April      F  10587   Sanchez
# 5190   NaN     Andrew      M  10934   Compton
#
# [5191 rows x 5 columns]

# %%
import pandas as pd

df_2.rename(columns={'id': 'customer_id'}, inplace=True)

df_2
# Out:
#        age first_name gender  customer_id last_name
# 0     48.0   Nicholas      M            0    Flores
# 1      NaN    Jeffery      M            1      Rowe
# 2     57.0     Alexis      F            2    Benton
# 3     73.0        Amy      F            3   Johnson
# 4     20.0      David      M            4     Moore
# ...    ...        ...    ...          ...       ...
# 5186   NaN     Arthur      M         9428    Harris
# 5187   NaN      David      M         9494       Roy
# 5188  85.0     Thomas      M        10350    Turner
# 5189   NaN      April      F        10587   Sanchez
# 5190   NaN     Andrew      M        10934   Compton
#
# [5191 rows x 5 columns]

# %%
complete_df = pd.merge(
    df_1,
    df_2,
    how='inner',
    left_on='customer_id',
    right_on='customer_id'
)

complete_df
# Out:
#       invoice_no  customer_id   category  quantity    price payment_method  \
# 0        I138884          229   Clothing         5  1500.40    Credit Card
# 1        I126377          229  Cosmetics         2    81.32    Credit Card
# 2        I178419          229      Shoes         3  1800.51     Debit Card
# 3        I847727          229   Clothing         3   900.24    Credit Card
# 4        I219251          229      Shoes         5  3000.85    Credit Card
# ...          ...          ...        ...       ...      ...            ...
# 99452    I198027         4973      Shoes         1   600.17           Cash
# 99453    I989120         6161      Books         5    75.75           Cash
# 99454    I791963         6779   Clothing         5  1500.40    Credit Card
# 99455    I100582         8386   Clothing         2   600.16           Cash
# 99456    I934204         4761  Cosmetics         4   162.64           Cash
#
#       invoice_date   shopping_mall   age first_name gender last_name
# ...

# %%
df_over = complete_df[complete_df['age'] > 45.0]

df_over
# Out:
#       invoice_no  customer_id   category  quantity    price payment_method  \
# 83       I127801          644   Clothing         1   300.08           Cash
# 84       I198233          644  Cosmetics         4   162.64           Cash
# 85       I225178          644   Clothing         5  1500.40    Credit Card
# 86       I310772          644      Shoes         5  3000.85           Cash
# 87       I712882          644   Clothing         4  1200.32           Cash
# ...          ...          ...        ...       ...      ...            ...
# 99441    I981269         4249      Shoes         5  3000.85     Debit Card
# 99444    I154835         8889       Toys         3   107.52           Cash
# 99449    I251260         4090   Souvenir         5    58.65    Credit Card
# 99455    I100582         8386   Clothing         2   600.16           Cash
# 99456    I934204         4761  Cosmetics         4   162.64           Cash
#
# ...

# %%
df_over.sum()['price']
# Out:
# 22370553.27

# %% [markdown]
# ## Question 3

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_1 = pd.read_csv('fct_invoice.csv')

df_1
# Out:
#       invoice_no  customer_id         category  quantity    price  \
# 0        I138884          229         Clothing         5  1500.40
# 1        I317333         3433            Shoes         3  1800.51
# 2        I127801          644         Clothing         1   300.08
# 3        I173702         4900            Shoes         5  3000.85
# 4        I337046         1089            Books         4    60.60
# ...          ...          ...              ...       ...      ...
# 99452    I219422         2344         Souvenir         5    58.65
# 99453    I325143          172  Food & Beverage         2    10.46
# 99454    I824010          425  Food & Beverage         2    10.46
# 99455    I702964          577       Technology         4  4200.00
# 99456    I232867           30         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# ...

# %%
df_1.sort_values('invoice_date')
# Out:
#       invoice_no  customer_id         category  quantity    price  \
# 36199    I192911          971  Food & Beverage         5    26.15
# 45626    I371949         1818             Toys         2    71.68
# 74986    I274757           14        Cosmetics         2    81.32
# 9456     I323282          624            Shoes         5  3000.85
# 36006    I263376          298  Food & Beverage         5    26.15
# ...          ...          ...              ...       ...      ...
# 5443     I142487          581            Shoes         1   600.17
# 92297    I156458         1909            Shoes         3  1800.51
# 45393    I162130         1566             Toys         1    35.84
# 5555     I298518          273         Clothing         4  1200.32
# 15220    I138457         1287        Cosmetics         1    40.66
#
#       payment_method invoice_date      shopping_mall
# 36199    Credit Card     1/1/2021          Metrocity
# 45626    Credit Card     1/1/2021          Metrocity
# ...

# %%
frequency = df_1.value_counts('invoice_date')

frequency
# Out:
# invoice_date
# 24/11/2021    159
# 26/02/2023    156
# 25/07/2022    155
# 23/10/2022    155
# 6/1/2021      155
#              ...
# 29/05/2021     98
# 27/10/2021     98
# 30/09/2021     96
# 2/12/2021      94
# 16/01/2022     93
# Length: 797, dtype: int64

# %%
for_graph = frequency.sort_index()

for_graph
# Out:
# invoice_date
# 1/1/2021     105
# 1/1/2022     101
# 1/1/2023     145
# 1/10/2021    132
# 1/10/2022    126
#             ...
# 9/7/2022     110
# 9/8/2021     135
# 9/8/2022     126
# 9/9/2021     136
# 9/9/2022     138
# Length: 797, dtype: int64

# %%
plt.plot(for_graph.index, for_graph.values)
plt.xlabel('Invoice Date')
plt.ylabel('Frequency')
plt.title('Frequency of Dates')
plt.show()

# %%
def get_season(date):
    month_day = date.strftime('%m-%d')
    seasons = {'Spring': [('03-01', '05-31')],
               'Summer': [('06-01', '08-31')],
               'Autumn': [('09-01', '11-30')],
               'Winter': [('12-01', '12-31'), ('01-01', '02-28')]}
    for season, date_ranges in seasons.items():
        for date_range in date_ranges:
            start, end = date_range
            if start <= month_day <= end:
                return season
        
df_1['season'] = df_1['invoice_date'].apply(get_season)

df_1
# Out:
#       invoice_no  customer_id         category  quantity    price  \
# 0        I138884          229         Clothing         5  1500.40
# 1        I317333         3433            Shoes         3  1800.51
# 2        I127801          644         Clothing         1   300.08
# 3        I173702         4900            Shoes         5  3000.85
# 4        I337046         1089            Books         4    60.60
# ...          ...          ...              ...       ...      ...
# 99452    I219422         2344         Souvenir         5    58.65
# 99453    I325143          172  Food & Beverage         2    10.46
# 99454    I824010          425  Food & Beverage         2    10.46
# 99455    I702964          577       Technology         4  4200.00
# 99456    I232867           30         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall  season
# 0        Credit Card   2022-05-08            Kanyon  Spring
# ...

# %%
df_1.sort_values('invoice_date')
# Out:
#       invoice_no  customer_id         category  quantity    price  \
# 38995    I765482          302         Clothing         5  1500.40
# 70063    I114774         2135         Souvenir         1    11.73
# 36955    I966320         1868         Clothing         3   900.24
# 29200    I298375         1343  Food & Beverage         2    10.46
# 29201    I223096         1569        Cosmetics         3   121.98
# ...          ...          ...              ...       ...      ...
# 15127    I202306          560             Toys         1    35.84
# 32544    I250697         3784         Clothing         5  1500.40
# 61735    I278408          229         Clothing         3   900.24
# 39915    I152068         1407             Toys         4   143.36
# 65206    I162740           84             Toys         4   143.36
#
#       payment_method invoice_date     shopping_mall  season
# 38995    Credit Card   2021-01-01            Kanyon  Winter
# ...

# %%
season_graph = df_1.value_counts('season')

season_graph
# Out:
# season
# Winter    27656
# Spring    24232
# Summer    24206
# Autumn    23363
# dtype: int64

# %%
plt.plot(season_graph.index, season_graph.values)
plt.xlabel('Season')
plt.ylabel('Frequency')
plt.title('Frequency of Seasons')
plt.show()

# %%
#During the winter season (whatever the year is), the number of people buying is at its peak. This may be because of the numerous holidays and celebrations such as Christmas and New Year present during this season.

# %% [markdown]
# # Hard

# %% [markdown]
# ## Question 1

# %%
import pandas as pd

df_1 = pd.read_csv('fct_invoice.csv')
df_2 = pd.read_json('dim_customer.json')

complete_df = pd.merge(
    df_1,
    df_2,
    how='inner',
    left_on='customer_id',
    right_on='id'
)

complete_df
# Out:
#       invoice_no  customer_id   category  quantity    price payment_method  \
# 0        I138884          229   Clothing         5  1500.40    Credit Card
# 1        I126377          229  Cosmetics         2    81.32    Credit Card
# 2        I178419          229      Shoes         3  1800.51     Debit Card
# 3        I847727          229   Clothing         3   900.24    Credit Card
# 4        I219251          229      Shoes         5  3000.85    Credit Card
# ...          ...          ...        ...       ...      ...            ...
# 99452    I198027         4973      Shoes         1   600.17           Cash
# 99453    I989120         6161      Books         5    75.75           Cash
# 99454    I791963         6779   Clothing         5  1500.40    Credit Card
# 99455    I100582         8386   Clothing         2   600.16           Cash
# 99456    I934204         4761  Cosmetics         4   162.64           Cash
#
# ...

# %%
def decade_age(age):
    return f'{(age // 10) * 10}-{(age // 10) * 10 + 9}'

complete_df['decade_age'] = complete_df['age'].apply(decade_age)

complete_df
# Out:
#       invoice_no  customer_id   category  quantity    price payment_method  \
# 0        I138884          229   Clothing         5  1500.40    Credit Card
# 1        I126377          229  Cosmetics         2    81.32    Credit Card
# 2        I178419          229      Shoes         3  1800.51     Debit Card
# 3        I847727          229   Clothing         3   900.24    Credit Card
# 4        I219251          229      Shoes         5  3000.85    Credit Card
# ...          ...          ...        ...       ...      ...            ...
# 99452    I198027         4973      Shoes         1   600.17           Cash
# 99453    I989120         6161      Books         5    75.75           Cash
# 99454    I791963         6779   Clothing         5  1500.40    Credit Card
# 99455    I100582         8386   Clothing         2   600.16           Cash
# 99456    I934204         4761  Cosmetics         4   162.64           Cash
#
# ...

# %%
complete_df.sort_values('decade_age')
# Out:
#       invoice_no  customer_id  category  quantity    price payment_method  \
# 70909    I988064          368  Clothing         5  1500.40    Credit Card
# 92338    I297234         2290     Shoes         2  1200.34           Cash
# 92339    I787705         2290      Toys         2    71.68     Debit Card
# 92340    I244744         2290      Toys         4   143.36    Credit Card
# 92341    I147227         2290  Clothing         4  1200.32     Debit Card
# ...          ...          ...       ...       ...      ...            ...
# 66034    I283783          245  Clothing         4  1200.32           Cash
# 66035    I267016          245     Shoes         1   600.17    Credit Card
# 66036    I240940          245  Clothing         5  1500.40           Cash
# 66016    I104097         2088  Clothing         4  1200.32     Debit Card
# 0        I138884          229  Clothing         5  1500.40    Credit Card
#
#       invoice_date     shopping_mall   age first_name gender    id last_name  \
# ...

# %%
pivot_table = pd.pivot_table(complete_df, values='price', index='category', columns='decade_age', aggfunc='sum')

pivot_table
# Out:
# decade_age       10.0-19.0   20.0-29.0   30.0-39.0   40.0-49.0   50.0-59.0  \
# category
# Books              3469.35    21619.05    22997.70    23361.30    20664.60
# Clothing         518238.16  2818351.36  3074919.76  3066817.60  2803647.44
# Cosmetics         29681.80   165079.60   198054.86   181343.60   160932.28
# Food & Beverage    3645.31    20428.38    23744.20    24460.71    19999.52
# Shoes            274277.69  1630061.72  1912141.62  1889335.16  1591650.84
# Souvenir           3296.13    15295.92    17548.08    17759.22    15084.78
# Technology       287700.00  1426950.00  1669500.00  1630650.00  1220100.00
# Toys              17203.20   102466.56   115297.28   106910.72    94115.84
#
# decade_age        60.0-69.0   70.0-79.0   80.0-89.0      nan-nan
# category
# Books              21513.00    15437.85     7575.00     90339.45
# Clothing         2910776.00  2117064.40  1228827.60  12537042.32
# Cosmetics         176627.04   114132.62    71236.32    751518.78
# ...
